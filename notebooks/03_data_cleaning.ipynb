# %% [markdown]
# STEP 3: Data Cleaning & Preprocessing

# %% [markdown]
# This notebook focuses on cleaning the raw loan dataset and
# preparing it for machine learning and explainable decision-making.
#
# Key goals:
# - Handle missing values responsibly
# - Encode categorical variables
# - Preserve interpretability
# - Prepare clean, reproducible data

# %% [markdown]
# 1. IMPORTS

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 2. LOAD RAW DATA

# %%
df = pd.read_csv(
    r"E:\ALL Documents\LEVEL 6 Completed\Projects\Week 1 AI & ML & Linux\end-to-end-explainable-ai-system\data\raw\loan-prediction-dataset.csv"
)

df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %% [markdown]
# 3. CHECK MISSING VALUES

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# 4. HANDLE MISSING NUMERICAL VALUES

# %%
df['LoanAmount'].fillna(df['LoanAmount'].median(), inplace=True)
df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].median, inplace=True)
# Out:
# C:\Users\Abdullah\AppData\Local\Temp\ipykernel_16928\1371421753.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['LoanAmount'].fillna(df['LoanAmount'].median(), inplace=True)
# C:\Users\Abdullah\AppData\Local\Temp\ipykernel_16928\1371421753.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<bound method Series.median of 0      360.0
# 1      360.0
# 2      360.0
# 3      360.0
# 4      360.0
#        ...
# 609    360.0
# 610    180.0
# 611    360.0
# 612    360.0
# 613    360.0
# Name: Loan_Amount_Term, Length: 614, dtype: float64>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].median, inplace=True)

# %%
df['LoanAmount'].isnull().sum()
df['Loan_Amount_Term'].isnull().sum()
# Out:
# 0

# %% [markdown]
# 6. HANDLE CREDIT HISTORY

# %%
df['Credit_History'].fillna(df['Credit_History'].mode()[0], inplace=True)
# Out:
# C:\Users\Abdullah\AppData\Local\Temp\ipykernel_16928\1608471621.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Credit_History'].fillna(df['Credit_History'].mode()[0], inplace=True)

# %%
df['Credit_History'].isnull().sum()
# Out:
# 0

# %% [markdown]
# 7. HANDLE CATEGORICAL MISSING VALUES

# %%
categorical_col = [
    'Gender', 'Married', 'Dependents',
    'Self_Employed'
]

for col in categorical_col:
    df[col].fillna(df[col].mode()[0], inplace=True)
# Out:
# C:\Users\Abdullah\AppData\Local\Temp\ipykernel_16928\635020018.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mode()[0], inplace=True)

# %%
df[categorical_col].isnull().sum()
# Out:
# Gender           0
# Married          0
# Dependents       0
# Self_Employed    0
# dtype: int64

# %% [markdown]
# 8. VERIFY NO MISSING VALUES

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %% [markdown]
# 9. ENCODE CATEGORICAL VARIABLES

# %%
binary_mapping = {
    'Y': 1,
    'N': 0
}

df['Loan_Status'] = df['Loan_Status'].map(binary_mapping)

# %%
df = pd.get_dummies(
    df,
    columns=[
        'Gender', 'Married', 'Dependents',
        'Education', 'Self_Employed',
        'Property_Area'
    ],
    drop_first=True
)

# %% [markdown]
# 10. FINAL DATA CHECK

# %%
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Loan_ID                  614 non-null    object
#  1   ApplicantIncome          614 non-null    int64
#  2   CoapplicantIncome        614 non-null    float64
#  3   LoanAmount               614 non-null    float64
#  4   Loan_Amount_Term         614 non-null    object
#  5   Credit_History           614 non-null    float64
#  6   Loan_Status              614 non-null    int64
#  7   Gender_Male              614 non-null    bool
#  8   Married_Yes              614 non-null    bool
#  9   Dependents_1             614 non-null    bool
#  10  Dependents_2             614 non-null    bool
#  11  Dependents_3+            614 non-null    bool
#  12  Education_Not Graduate   614 non-null    bool
#  13  Self_Employed_Yes        614 non-null    bool
#  14  Property_Area_Semiurban  614 non-null    bool
#  15  Property_Area_Urban      614 non-null    bool
# dtypes: bool(9), float64(3), int64(2), object(2)
# memory usage: 39.1+ KB

# %% [markdown]
# 11. SAVE CLEANED DATA (IMPORTANT)

# %%
df.to_csv("../data/processed/cleaned_data.csv", index=False)
